# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind-chilakamarri/CS5001-Fundamentals-of-Data-Engineering/blob/main/Project_3_CSV_TSV_JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Complete the following steps in Colab and submit the resulting ipynb (interactive python notebook, also
# known as Jupyter notebook) file to Canvas.
# 1. Log in to Colab.
# 2. Create a new notebook and name it as Project#3-CSV TSV JSON.ipynb.
# 3. Make sure to fully understand a sample code given at
# https://colab.research.google.com/drive/1MtQElDK-CADfreJqi18_ijFWCqMag50I?usp=sharing
# This notebook shows you how to use faker library to generate synthetic data set for testing
# purposes. Note it creates a CSV file with 1 header row and 100 data records (rows).
# 4. Create a code cell and copy/paste the sample code to create a CSV (comma separated values)
# data file named sample_data.csv containing 1 header row and 1000 randomly generated data
# records (rows). Note that the text encoding selected is UTF-8 to support the last column where
# emojis are given.
# 5. Create a code cell to read the csv file. Then, transform the data. First, remove rows if state is not
# MO. Then, change SSN (Social Security Number) format. The given format is xxx-xx-xxxx. Change
# it to xxxxxxxxx by removing two dashes. Write the resulting data to a file named
# output_data.tsv. Make sure to use TSV (tab separated values) format.
# 6. Create a code cell to write the same transformed data to a file named output_data.json. Make
# sure to use JSON (JavaScript Object Notation) format.
# 7. Add a text cell after each code cell and explain what has been done.
# 8. Run the whole ipynb notebook to test it.
# 9. Download ipynb file.
# 10. Submit it to Canvas – Project#3-CSV TSV JSON.

# %%
# pip is python install package commandline utility
# ! mark is need to run commandline tools
# !pip install faker
import faker
import sys
import csv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 18.5 MB/s eta 0:00:00
# ...

# %%
from faker import Faker

# select locale of fake data
fake = Faker('en_US')

# open a csv file to write
# utf-8 text encoding is selected to support emoji
with open('sample_data.csv', mode='w',encoding='utf-8') as sample_data:
  writer = csv.writer(sample_data)

  writer.writerow(['Name','State','Plate','SSN','Occupation','Emoji'])
  for _ in range(1000):
    writer.writerow([fake.name(), fake.state_abbr(), fake.license_plate(),fake.ssn(),fake.job(),fake.emoji()])

# %% [markdown]
# #CREATE A PANDAS DATA FRAME BY LOADING THE GENERATED FAKE TABLE

# %%
import pandas as pd


df = pd.read_csv('/content/sample_data.csv')

df.head()
# Out:
#              Name State    Plate          SSN  \
# 0    Jordan Eaton    DE  98FP996  448-13-0032
# 1  Edward Preston    WV  4WFD 19  058-95-8150
# 2    Jessica Wood    CO  LCD-519  591-50-1526
# 3     April Perry    IL  ZNA 688  060-63-7867
# 4     Katie Smith    PW     7890  743-78-6821
#
#                         Occupation       Emoji
# 0              Designer, jewellery           🎽
# 1          Forest/woodland manager           🚙
# 2  Sport and exercise psychologist  👩🏽‍❤️‍💋‍👩🏻
# 3           Chief Strategy Officer        🧑🏿‍🦽
# 4                Film/video editor           😿

# %% [markdown]
# #DROP THE ROWS WHICH DOES NOT HAVE 'MO' IN STATE COLUMN

# %%
df.drop(df[df['State'] != 'MO'].index, inplace = True)

# %%
df.head()
# Out:
#                  Name State    Plate          SSN  \
# 58   Michelle Perkins    MO  647-TIY  140-17-1258
# 103   Michael Elliott    MO  YMQ 687  557-60-9982
# 146    Nicholas Perez    MO  XU 5705  088-89-4033
# 161     Ronald Taylor    MO  618 YDN  636-05-1991
# 220     Morgan Miller    MO  KVA 858  312-17-4634
#
#                                 Occupation Emoji
# 58   Emergency planning/management officer  🧖‍♀️
# 103                             Geochemist    🧚🏻
# 146                  Accountant, chartered    🇳🇱
# 161                                Actuary    👰🏼
# 220                           Risk analyst  👨🏻‍🦽

# %% [markdown]
# #WRITE A FUNCTION WHICH TAKES IN A VALUE AND MODIFY IT TO THE WAY WE WANT

# %%
def format_ssn(x):
    return ''.join(x.split('-'))

# %% [markdown]
# #PASS THE FUNCTION TO THE MAP FUNCTION TO AFFECT THE CHANGES

# %%
df['SSN'] = df['SSN'].map(format_ssn)
df.head()
# Out:
#                  Name State    Plate        SSN  \
# 58   Michelle Perkins    MO  647-TIY  140171258
# 103   Michael Elliott    MO  YMQ 687  557609982
# 146    Nicholas Perez    MO  XU 5705  088894033
# 161     Ronald Taylor    MO  618 YDN  636051991
# 220     Morgan Miller    MO  KVA 858  312174634
#
#                                 Occupation Emoji
# 58   Emergency planning/management officer  🧖‍♀️
# 103                             Geochemist    🧚🏻
# 146                  Accountant, chartered    🇳🇱
# 161                                Actuary    👰🏼
# 220                           Risk analyst  👨🏻‍🦽

# %% [markdown]
# #JUST LIKE CSV, SAVE TO TSV BY GIVING TAB PLACEHOLDER AS A SEPARATOR

# %%
df.to_csv('output_data.tsv', sep="\t")

# %% [markdown]
# #to_json IS USED TO SAVE IN JSON FORMAT

# %%
df.to_json('output_data.json')
